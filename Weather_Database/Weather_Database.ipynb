# %%
##3 Create a new set of 2,000 random latitudes and longitudes
# Import the random module.
import random

# %%
random.random()
# Out:
# 0.3086815533993015

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
##for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
##5.Perform an API call with the OpenWeatherMap.

# Import the requests library.
import requests
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2dde9c88144d3b999edf1c86235888bc

# %% [markdown]
# ### 6Retrieve the following information from the API call:
# #### 1Latitude and longitude
# #### 2Maximum temperature
# #### 3Percent humidity
# #### 4Percent cloudiness
# #### 5Wind speed
# #### 6Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Weather description (for example, clouds, fog, light rain, clear sky)

        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Country": city_country, 
                         "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | omsukchan
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | sapa
# Processing Record 5 of Set 1 | soyo
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | romanovka
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | kembe
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | hofn
# Processing Record 16 of Set 1 | sterling
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | fort saint james
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | zhigansk
# Processing Record 24 of Set 1 | grindavik
# Processing Record 25 of Set 1 | san carlos de bariloche
# Processing Record 26 of Set 1 | vardo
# Processing Record 27 of Set 1 | barcelos
# Processing Record 28 of Set 1 | kaitangata
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | severnyy
# Processing Record 31 of Set 1 | shitanjing
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | luwuk
# Processing Record 39 of Set 1 | auki
# Processing Record 40 of Set 1 | sile
# Processing Record 41 of Set 1 | westerly
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | jumla
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | batagay-alyta
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | port blair
# Processing Record 49 of Set 1 | mahibadhoo
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | muros
# Processing Record 3 of Set 2 | masindi
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | sinnamary
# Processing Record 9 of Set 2 | ketchikan
# Processing Record 10 of Set 2 | roma
# Processing Record 11 of Set 2 | kingman
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | inhambane
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | cabedelo
# Processing Record 16 of Set 2 | carballo
# Processing Record 17 of Set 2 | jhang
# Processing Record 18 of Set 2 | noumea
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | mehamn
# Processing Record 22 of Set 2 | ambatondrazaka
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | melk
# Processing Record 25 of Set 2 | koumac
# Processing Record 26 of Set 2 | baboua
# City not found. Skipping...
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | yatou
# Processing Record 29 of Set 2 | yamada
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | straumen
# Processing Record 33 of Set 2 | ouagadougou
# Processing Record 34 of Set 2 | tuktoyaktuk
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | ulladulla
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | port alberni
# Processing Record 42 of Set 2 | hasaki
# Processing Record 43 of Set 2 | luanda
# Processing Record 44 of Set 2 | coahuayana
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | lavrentiya
# Processing Record 47 of Set 2 | vila franca do campo
# Processing Record 48 of Set 2 | japura
# Processing Record 49 of Set 2 | paiania
# Processing Record 50 of Set 2 | nagornyy
# Processing Record 1 of Set 3 | ayan
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | ucluelet
# Processing Record 4 of Set 3 | nome
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | bathsheba
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 3 | haines junction
# Processing Record 10 of Set 3 | asau
# Processing Record 11 of Set 3 | rosita
# Processing Record 12 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 3 | atasu
# Processing Record 14 of Set 3 | alofi
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | lebrija
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | bereda
# Processing Record 19 of Set 3 | cayenne
# Processing Record 20 of Set 3 | puerto ayora
# Processing Record 21 of Set 3 | bonavista
# Processing Record 22 of Set 3 | deputatskiy
# Processing Record 23 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | bara
# Processing Record 26 of Set 3 | aksu
# Processing Record 27 of Set 3 | paamiut
# Processing Record 28 of Set 3 | beinamar
# Processing Record 29 of Set 3 | saint george
# Processing Record 30 of Set 3 | vaini
# Processing Record 31 of Set 3 | elizabeth city
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | chamalieres
# Processing Record 34 of Set 3 | novoagansk
# Processing Record 35 of Set 3 | vallenar
# Processing Record 36 of Set 3 | staroleushkovskaya
# Processing Record 37 of Set 3 | cape town
# Processing Record 38 of Set 3 | cuiluan
# Processing Record 39 of Set 3 | mogadishu
# Processing Record 40 of Set 3 | oktyabrskoye
# Processing Record 41 of Set 3 | sistranda
# Processing Record 42 of Set 3 | san pedro
# Processing Record 43 of Set 3 | kavaratti
# Processing Record 44 of Set 3 | kautokeino
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | holly springs
# Processing Record 47 of Set 3 | tequila
# Processing Record 48 of Set 3 | bhuj
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | vestmannaeyjar
# Processing Record 2 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 4 | taseyevo
# Processing Record 4 of Set 4 | jiwani
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 4 | lagoa
# Processing Record 8 of Set 4 | springbok
# Processing Record 9 of Set 4 | pangkalanbuun
# Processing Record 10 of Set 4 | veracruz
# Processing Record 11 of Set 4 | quatre cocos
# Processing Record 12 of Set 4 | dunedin
# Processing Record 13 of Set 4 | adrar
# Processing Record 14 of Set 4 | kapiri mposhi
# Processing Record 15 of Set 4 | port lincoln
# Processing Record 16 of Set 4 | dingzhou
# Processing Record 17 of Set 4 | salym
# Processing Record 18 of Set 4 | tura
# Processing Record 19 of Set 4 | mbandaka
# Processing Record 20 of Set 4 | vanimo
# Processing Record 21 of Set 4 | mombetsu
# Processing Record 22 of Set 4 | concordia
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | goya
# Processing Record 25 of Set 4 | erenhot
# Processing Record 26 of Set 4 | lasa
# Processing Record 27 of Set 4 | nouadhibou
# Processing Record 28 of Set 4 | almeirim
# Processing Record 29 of Set 4 | mayo
# Processing Record 30 of Set 4 | nioro
# Processing Record 31 of Set 4 | chuy
# Processing Record 32 of Set 4 | candido mendes
# Processing Record 33 of Set 4 | praia
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | celina
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | plonsk
# Processing Record 38 of Set 4 | sorgun
# Processing Record 39 of Set 4 | san miguel
# Processing Record 40 of Set 4 | bridlington
# Processing Record 41 of Set 4 | visby
# Processing Record 42 of Set 4 | xinpu
# Processing Record 43 of Set 4 | arklow
# Processing Record 44 of Set 4 | carnarvon
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | almaznyy
# Processing Record 48 of Set 4 | gigmoto
# Processing Record 49 of Set 4 | saint-francois
# Processing Record 50 of Set 4 | santiago
# Processing Record 1 of Set 5 | arawa
# Processing Record 2 of Set 5 | jacareacanga
# Processing Record 3 of Set 5 | puerto narino
# Processing Record 4 of Set 5 | boa vista
# Processing Record 5 of Set 5 | dzheyrakh
# Processing Record 6 of Set 5 | khasan
# Processing Record 7 of Set 5 | leopold
# Processing Record 8 of Set 5 | college
# Processing Record 9 of Set 5 | saint-augustin
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | korla
# Processing Record 12 of Set 5 | ambon
# Processing Record 13 of Set 5 | bassila
# Processing Record 14 of Set 5 | kalevala
# Processing Record 15 of Set 5 | port elizabeth
# Processing Record 16 of Set 5 | rafai
# Processing Record 17 of Set 5 | windhoek
# Processing Record 18 of Set 5 | yerbogachen
# Processing Record 19 of Set 5 | cidreira
# Processing Record 20 of Set 5 | vytegra
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | erzin
# Processing Record 23 of Set 5 | berlevag
# Processing Record 24 of Set 5 | pangody
# Processing Record 25 of Set 5 | orcotuna
# Processing Record 26 of Set 5 | oistins
# Processing Record 27 of Set 5 | pacific grove
# Processing Record 28 of Set 5 | ambilobe
# Processing Record 29 of Set 5 | port hardy
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | masumbwe
# Processing Record 32 of Set 5 | ayolas
# Processing Record 33 of Set 5 | stephenville
# Processing Record 34 of Set 5 | komsomolskiy
# Processing Record 35 of Set 5 | vila velha
# Processing Record 36 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 5 | todos santos
# Processing Record 38 of Set 5 | humberto de campos
# Processing Record 39 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | nova odesa
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | bireun
# Processing Record 44 of Set 5 | bambous virieux
# Processing Record 45 of Set 5 | yulara
# Processing Record 46 of Set 5 | seewalchen
# Processing Record 47 of Set 5 | nuuk
# Processing Record 48 of Set 5 | bandarbeyla
# Processing Record 49 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 5 | kencong
# Processing Record 1 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 6 | grand-santi
# Processing Record 3 of Set 6 | a
# City not found. Skipping...
# Processing Record 4 of Set 6 | rocha
# Processing Record 5 of Set 6 | saskylakh
# Processing Record 6 of Set 6 | skorodnoye
# Processing Record 7 of Set 6 | zalantun
# Processing Record 8 of Set 6 | egvekinot
# Processing Record 9 of Set 6 | anadyr
# Processing Record 10 of Set 6 | teguldet
# Processing Record 11 of Set 6 | khuzhir
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | bitkine
# Processing Record 14 of Set 6 | alekseyevka
# Processing Record 15 of Set 6 | amahai
# Processing Record 16 of Set 6 | atar
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | ulsteinvik
# Processing Record 19 of Set 6 | hamilton
# Processing Record 20 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 6 | cavalcante
# Processing Record 22 of Set 6 | gondanglegi
# Processing Record 23 of Set 6 | maralal
# Processing Record 24 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | tual
# Processing Record 27 of Set 6 | kouango
# Processing Record 28 of Set 6 | longyearbyen
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | buchach
# Processing Record 31 of Set 6 | tripoli
# Processing Record 32 of Set 6 | gejiu
# Processing Record 33 of Set 6 | vanino
# Processing Record 34 of Set 6 | morondava
# Processing Record 35 of Set 6 | vostok
# Processing Record 36 of Set 6 | ostroleka
# Processing Record 37 of Set 6 | husavik
# Processing Record 38 of Set 6 | baykit
# Processing Record 39 of Set 6 | veraval
# Processing Record 40 of Set 6 | pozo colorado
# Processing Record 41 of Set 6 | evensk
# Processing Record 42 of Set 6 | berdigestyakh
# Processing Record 43 of Set 6 | sao joao da barra
# Processing Record 44 of Set 6 | lively
# Processing Record 45 of Set 6 | karpathos
# Processing Record 46 of Set 6 | chitungwiza
# Processing Record 47 of Set 6 | bhadrachalam
# Processing Record 48 of Set 6 | chapais
# Processing Record 49 of Set 6 | dingle
# Processing Record 50 of Set 6 | dongying
# Processing Record 1 of Set 7 | surt
# Processing Record 2 of Set 7 | daru
# Processing Record 3 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 7 | pisco
# Processing Record 5 of Set 7 | khadro
# Processing Record 6 of Set 7 | itaituba
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | dudinka
# Processing Record 9 of Set 7 | capreol
# Processing Record 10 of Set 7 | mafra
# Processing Record 11 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 7 | havre-saint-pierre
# Processing Record 13 of Set 7 | price
# Processing Record 14 of Set 7 | merrill
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | nemsova
# Processing Record 17 of Set 7 | katsuura
# Processing Record 18 of Set 7 | hami
# Processing Record 19 of Set 7 | maldonado
# Processing Record 20 of Set 7 | lahaina
# Processing Record 21 of Set 7 | kupang
# Processing Record 22 of Set 7 | abu samrah
# Processing Record 23 of Set 7 | iskateley
# Processing Record 24 of Set 7 | general roca
# Processing Record 25 of Set 7 | brae
# Processing Record 26 of Set 7 | tornio
# Processing Record 27 of Set 7 | west wendover
# Processing Record 28 of Set 7 | bantry
# Processing Record 29 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 7 | itupiranga
# Processing Record 31 of Set 7 | walvis bay
# Processing Record 32 of Set 7 | hithadhoo
# Processing Record 33 of Set 7 | flinders
# Processing Record 34 of Set 7 | xai-xai
# Processing Record 35 of Set 7 | omboue
# Processing Record 36 of Set 7 | salalah
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | williston
# Processing Record 39 of Set 7 | krasnogorsk
# Processing Record 40 of Set 7 | gisborne
# Processing Record 41 of Set 7 | buala
# Processing Record 42 of Set 7 | taksimo
# Processing Record 43 of Set 7 | gizo
# Processing Record 44 of Set 7 | airai
# Processing Record 45 of Set 7 | jerome
# Processing Record 46 of Set 7 | pachino
# Processing Record 47 of Set 7 | mnogovershinnyy
# Processing Record 48 of Set 7 | maningrida
# Processing Record 49 of Set 7 | vyyezdnoye
# Processing Record 50 of Set 7 | ferme-neuve
# Processing Record 1 of Set 8 | fort morgan
# Processing Record 2 of Set 8 | lodhran
# Processing Record 3 of Set 8 | madera
# Processing Record 4 of Set 8 | onega
# Processing Record 5 of Set 8 | camacha
# Processing Record 6 of Set 8 | lorengau
# Processing Record 7 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 8 | kirakira
# Processing Record 9 of Set 8 | geraldton
# Processing Record 10 of Set 8 | znamenskoye
# Processing Record 11 of Set 8 | bonfim
# Processing Record 12 of Set 8 | christchurch
# Processing Record 13 of Set 8 | yumen
# Processing Record 14 of Set 8 | igarka
# Processing Record 15 of Set 8 | piney green
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | namatanai
# Processing Record 18 of Set 8 | changping
# Processing Record 19 of Set 8 | keetmanshoop
# Processing Record 20 of Set 8 | kahului
# Processing Record 21 of Set 8 | novikovo
# Processing Record 22 of Set 8 | shimoda
# Processing Record 23 of Set 8 | kanker
# Processing Record 24 of Set 8 | inirida
# Processing Record 25 of Set 8 | coquimbo
# Processing Record 26 of Set 8 | dongsheng
# Processing Record 27 of Set 8 | half moon bay
# Processing Record 28 of Set 8 | obo
# Processing Record 29 of Set 8 | den helder
# Processing Record 30 of Set 8 | hervey bay
# Processing Record 31 of Set 8 | alaverdi
# Processing Record 32 of Set 8 | rio branco
# Processing Record 33 of Set 8 | rabat
# Processing Record 34 of Set 8 | portland
# Processing Record 35 of Set 8 | dangriga
# Processing Record 36 of Set 8 | chivay
# Processing Record 37 of Set 8 | bokhan
# Processing Record 38 of Set 8 | tasiilaq
# Processing Record 39 of Set 8 | kualakapuas
# Processing Record 40 of Set 8 | manoel urbano
# Processing Record 41 of Set 8 | laguna
# Processing Record 42 of Set 8 | changli
# Processing Record 43 of Set 8 | svetlyy
# Processing Record 44 of Set 8 | kiunga
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | khandyga
# Processing Record 47 of Set 8 | victor harbor
# Processing Record 48 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 49 of Set 8 | san patricio
# Processing Record 50 of Set 8 | la ronge
# Processing Record 1 of Set 9 | mount isa
# Processing Record 2 of Set 9 | repalle
# Processing Record 3 of Set 9 | ostrovnoy
# Processing Record 4 of Set 9 | ramhormoz
# Processing Record 5 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 9 | vysokogornyy
# Processing Record 7 of Set 9 | bengkulu
# Processing Record 8 of Set 9 | olga
# Processing Record 9 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 9 | kloulklubed
# Processing Record 11 of Set 9 | hambantota
# Processing Record 12 of Set 9 | gornyy
# Processing Record 13 of Set 9 | margate
# Processing Record 14 of Set 9 | lydenburg
# Processing Record 15 of Set 9 | fort nelson
# Processing Record 16 of Set 9 | pietarsaari
# Processing Record 17 of Set 9 | sao filipe
# Processing Record 18 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 9 | bairiki
# Processing Record 20 of Set 9 | rakaia
# Processing Record 21 of Set 9 | kyaukse
# Processing Record 22 of Set 9 | kudahuvadhoo
# Processing Record 23 of Set 9 | natchitoches
# Processing Record 24 of Set 9 | rio gallegos
# Processing Record 25 of Set 9 | mar del plata
# Processing Record 26 of Set 9 | lodingen
# Processing Record 27 of Set 9 | viedma
# Processing Record 28 of Set 9 | gladstone
# Processing Record 29 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 30 of Set 9 | findlay
# Processing Record 31 of Set 9 | gazojak
# Processing Record 32 of Set 9 | san jose
# Processing Record 33 of Set 9 | fereydun kenar
# Processing Record 34 of Set 9 | byron bay
# Processing Record 35 of Set 9 | ouricuri
# Processing Record 36 of Set 9 | waipawa
# Processing Record 37 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 9 | linxia
# Processing Record 39 of Set 9 | namibe
# Processing Record 40 of Set 9 | vitre
# Processing Record 41 of Set 9 | tabuk
# Processing Record 42 of Set 9 | conceicao do araguaia
# Processing Record 43 of Set 9 | isabela
# Processing Record 44 of Set 9 | andreapol
# Processing Record 45 of Set 9 | rio grande
# Processing Record 46 of Set 9 | shirvan
# Processing Record 47 of Set 9 | mitsamiouli
# Processing Record 48 of Set 9 | olinda
# Processing Record 49 of Set 9 | porto novo
# Processing Record 50 of Set 9 | cairns
# Processing Record 1 of Set 10 | chara
# Processing Record 2 of Set 10 | porosozero
# Processing Record 3 of Set 10 | nanortalik
# Processing Record 4 of Set 10 | belturbet
# Processing Record 5 of Set 10 | yar-sale
# Processing Record 6 of Set 10 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | roald
# Processing Record 8 of Set 10 | santa cruz de tenerife
# Processing Record 9 of Set 10 | mandalgovi
# Processing Record 10 of Set 10 | alice springs
# Processing Record 11 of Set 10 | padang
# Processing Record 12 of Set 10 | mildura
# Processing Record 13 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 10 | manta
# Processing Record 15 of Set 10 | verkhoyansk
# Processing Record 16 of Set 10 | beyneu
# Processing Record 17 of Set 10 | muroto
# Processing Record 18 of Set 10 | hirado
# Processing Record 19 of Set 10 | vilyuysk
# Processing Record 20 of Set 10 | urumqi
# Processing Record 21 of Set 10 | ambanja
# Processing Record 22 of Set 10 | crossville
# Processing Record 23 of Set 10 | juneau
# Processing Record 24 of Set 10 | banjar
# Processing Record 25 of Set 10 | neiafu
# Processing Record 26 of Set 10 | chumikan
# Processing Record 27 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 10 | areia branca
# Processing Record 29 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 10 | nabire
# Processing Record 31 of Set 10 | durg
# Processing Record 32 of Set 10 | clarence town
# Processing Record 33 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 34 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 10 | wanlaweyn
# Processing Record 36 of Set 10 | caluquembe
# Processing Record 37 of Set 10 | wanning
# Processing Record 38 of Set 10 | malaya
# Processing Record 39 of Set 10 | yuancheng
# Processing Record 40 of Set 10 | pocoes
# Processing Record 41 of Set 10 | saint-joseph
# Processing Record 42 of Set 10 | arcachon
# Processing Record 43 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 10 | thinadhoo
# Processing Record 46 of Set 10 | garoua
# Processing Record 47 of Set 10 | rennes
# Processing Record 48 of Set 10 | shenjiamen
# Processing Record 49 of Set 10 | cabra
# Processing Record 50 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 1 of Set 11 | copiapo
# Processing Record 2 of Set 11 | ahipara
# Processing Record 3 of Set 11 | altayskoye
# Processing Record 4 of Set 11 | pangnirtung
# Processing Record 5 of Set 11 | birin
# Processing Record 6 of Set 11 | viseu
# Processing Record 7 of Set 11 | iqaluit
# Processing Record 8 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 11 | waingapu
# Processing Record 10 of Set 11 | senador jose porfirio
# Processing Record 11 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 11 | vanavara
# Processing Record 14 of Set 11 | samarai
# Processing Record 15 of Set 11 | mabaruma
# Processing Record 16 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 17 of Set 11 | gidam
# Processing Record 18 of Set 11 | bismarck
# Processing Record 19 of Set 11 | vao
# Processing Record 20 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 11 | pemangkat
# Processing Record 22 of Set 11 | salur
# Processing Record 23 of Set 11 | yashan
# Processing Record 24 of Set 11 | anandnagar
# Processing Record 25 of Set 11 | camana
# Processing Record 26 of Set 11 | sitka
# Processing Record 27 of Set 11 | mezen
# Processing Record 28 of Set 11 | vrangel
# Processing Record 29 of Set 11 | tompa
# Processing Record 30 of Set 11 | manbij
# Processing Record 31 of Set 11 | duki
# Processing Record 32 of Set 11 | lata
# Processing Record 33 of Set 11 | lamar
# Processing Record 34 of Set 11 | meulaboh
# Processing Record 35 of Set 11 | narsaq
# Processing Record 36 of Set 11 | matay
# Processing Record 37 of Set 11 | fairbanks
# Processing Record 38 of Set 11 | weligama
# Processing Record 39 of Set 11 | honiara
# Processing Record 40 of Set 11 | cam ranh
# Processing Record 41 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 11 | karabanovo
# Processing Record 43 of Set 11 | sainte-maxime
# Processing Record 44 of Set 11 | conceicao da barra
# Processing Record 45 of Set 11 | marshall
# Processing Record 46 of Set 11 | pilar
# Processing Record 47 of Set 11 | nemuro
# Processing Record 48 of Set 11 | coihaique
# Processing Record 49 of Set 11 | kokopo
# Processing Record 50 of Set 11 | bayangol
# Processing Record 1 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 12 | xapuri
# Processing Record 3 of Set 12 | edson
# Processing Record 4 of Set 12 | faya
# Processing Record 5 of Set 12 | sioux lookout
# Processing Record 6 of Set 12 | altay
# Processing Record 7 of Set 12 | mahajanga
# Processing Record 8 of Set 12 | mumford
# Processing Record 9 of Set 12 | batemans bay
# Processing Record 10 of Set 12 | agudos
# Processing Record 11 of Set 12 | bo
# City not found. Skipping...
# Processing Record 12 of Set 12 | eregli
# Processing Record 13 of Set 12 | axim
# Processing Record 14 of Set 12 | hirara
# Processing Record 15 of Set 12 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 16 of Set 12 | codrington
# Processing Record 17 of Set 12 | setermoen
# Processing Record 18 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 19 of Set 12 | mianyang
# Processing Record 20 of Set 12 | scottsboro
# Processing Record 21 of Set 12 | qaqortoq
# Processing Record 22 of Set 12 | saint anthony
# Processing Record 23 of Set 12 | pokhara
# Processing Record 24 of Set 12 | salinopolis
# Processing Record 25 of Set 12 | channel-port aux basques
# Processing Record 26 of Set 12 | cotonou
# Processing Record 27 of Set 12 | pevek
# Processing Record 28 of Set 12 | clyde river
# Processing Record 29 of Set 12 | sun valley
# Processing Record 30 of Set 12 | haputale
# Processing Record 31 of Set 12 | tiznit
# Processing Record 32 of Set 12 | ugoofaaru
# Processing Record 33 of Set 12 | ixtapa
# Processing Record 34 of Set 12 | south valley
# Processing Record 35 of Set 12 | bud
# Processing Record 36 of Set 12 | vyartsilya
# Processing Record 37 of Set 12 | ergani
# Processing Record 38 of Set 12 | snasa
# Processing Record 39 of Set 12 | kaabong
# Processing Record 40 of Set 12 | nchelenge
# Processing Record 41 of Set 12 | ust-koksa
# Processing Record 42 of Set 12 | synya
# Processing Record 43 of Set 12 | piacabucu
# Processing Record 44 of Set 12 | angoche
# Processing Record 45 of Set 12 | bandundu
# Processing Record 46 of Set 12 | jijiang
# Processing Record 47 of Set 12 | palmares do sul
# Processing Record 48 of Set 12 | sungaipenuh
# Processing Record 49 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 12 | vredendal
# Processing Record 1 of Set 13 | xiongyue
# Processing Record 2 of Set 13 | estelle
# Processing Record 3 of Set 13 | broken hill
# Processing Record 4 of Set 13 | henties bay
# Processing Record 5 of Set 13 | tuxpan
# Processing Record 6 of Set 13 | vuktyl
# Processing Record 7 of Set 13 | prince rupert
# Processing Record 8 of Set 13 | tra vinh
# Processing Record 9 of Set 13 | mocajuba
# Processing Record 10 of Set 13 | constitucion
# Processing Record 11 of Set 13 | garni
# Processing Record 12 of Set 13 | auray
# Processing Record 13 of Set 13 | multai
# Processing Record 14 of Set 13 | tazovskiy
# Processing Record 15 of Set 13 | sola
# Processing Record 16 of Set 13 | pasni
# Processing Record 17 of Set 13 | erdenet
# Processing Record 18 of Set 13 | oum hadjer
# Processing Record 19 of Set 13 | ngunguru
# Processing Record 20 of Set 13 | jasper
# Processing Record 21 of Set 13 | borgarnes
# Processing Record 22 of Set 13 | nirmali
# Processing Record 23 of Set 13 | freeport
# Processing Record 24 of Set 13 | lar
# Processing Record 25 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 26 of Set 13 | beidao
# Processing Record 27 of Set 13 | port-cartier
# Processing Record 28 of Set 13 | gilgil
# City not found. Skipping...
# Processing Record 29 of Set 13 | kamenka
# Processing Record 30 of Set 13 | isangel
# Processing Record 31 of Set 13 | garissa
# Processing Record 32 of Set 13 | bilma
# Processing Record 33 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 13 | ust-nera
# Processing Record 35 of Set 13 | ushibuka
# Processing Record 36 of Set 13 | agapovka
# Processing Record 37 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 13 | larap
# Processing Record 39 of Set 13 | vestmanna
# Processing Record 40 of Set 13 | andenes
# Processing Record 41 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 13 | manoharpur
# Processing Record 43 of Set 13 | tayu
# Processing Record 44 of Set 13 | nizwa
# Processing Record 45 of Set 13 | ternate
# Processing Record 46 of Set 13 | huarmey
# Processing Record 47 of Set 13 | canoinhas
# Processing Record 48 of Set 13 | choix
# Processing Record 49 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 13 | the valley
# Processing Record 1 of Set 14 | sambava
# Processing Record 2 of Set 14 | redondela
# Processing Record 3 of Set 14 | hobyo
# Processing Record 4 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 14 | stepnyak
# Processing Record 6 of Set 14 | esil
# Processing Record 7 of Set 14 | teya
# Processing Record 8 of Set 14 | springdale
# Processing Record 9 of Set 14 | szentgotthard
# Processing Record 10 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 14 | kjollefjord
# Processing Record 13 of Set 14 | kunashak
# Processing Record 14 of Set 14 | beringovskiy
# Processing Record 15 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 14 | corner brook
# Processing Record 17 of Set 14 | along
# Processing Record 18 of Set 14 | mastic beach
# Processing Record 19 of Set 14 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 20 of Set 14 | rawson
# Processing Record 21 of Set 14 | wattegama
# Processing Record 22 of Set 14 | mount gambier
# Processing Record 23 of Set 14 | seymchan
# Processing Record 24 of Set 14 | mkushi
# Processing Record 25 of Set 14 | cururupu
# Processing Record 26 of Set 14 | prachuap khiri khan
# Processing Record 27 of Set 14 | iquique
# Processing Record 28 of Set 14 | pouembout
# Processing Record 29 of Set 14 | norton shores
# Processing Record 30 of Set 14 | vilhena
# Processing Record 31 of Set 14 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 32 of Set 14 | matara
# Processing Record 33 of Set 14 | naze
# Processing Record 34 of Set 14 | labuhan
# Processing Record 35 of Set 14 | micheweni
# Processing Record 36 of Set 14 | ramasukha
# City not found. Skipping...
# Processing Record 37 of Set 14 | gryazi
# Processing Record 38 of Set 14 | puerto escondido
# Processing Record 39 of Set 14 | hakui
# Processing Record 40 of Set 14 | presidente epitacio
# Processing Record 41 of Set 14 | mecca
# Processing Record 42 of Set 14 | pocinhos
# Processing Record 43 of Set 14 | sabang
# Processing Record 44 of Set 14 | tucuman
# Processing Record 45 of Set 14 | falun
# Processing Record 46 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 47 of Set 14 | bowen
# Processing Record 48 of Set 14 | jalu
# Processing Record 49 of Set 14 | dayong
# Processing Record 50 of Set 14 | bajil
# Processing Record 1 of Set 15 | takaka
# Processing Record 2 of Set 15 | preston
# Processing Record 3 of Set 15 | guapore
# Processing Record 4 of Set 15 | san quintin
# Processing Record 5 of Set 15 | kurilsk
# Processing Record 6 of Set 15 | tukrah
# Processing Record 7 of Set 15 | sokolow podlaski
# Processing Record 8 of Set 15 | jinchang
# Processing Record 9 of Set 15 | jawar
# Processing Record 10 of Set 15 | rovnoye
# Processing Record 11 of Set 15 | abilene
# Processing Record 12 of Set 15 | dicabisagan
# Processing Record 13 of Set 15 | roebourne
# Processing Record 14 of Set 15 | tigil
# Processing Record 15 of Set 15 | awjilah
# Processing Record 16 of Set 15 | meridian
# Processing Record 17 of Set 15 | zhangye
# Processing Record 18 of Set 15 | bossangoa
# Processing Record 19 of Set 15 | bozeman
# Processing Record 20 of Set 15 | puerto el triunfo
# Processing Record 21 of Set 15 | dali
# Processing Record 22 of Set 15 | ossora
# Processing Record 23 of Set 15 | dzerzhinskoye
# Processing Record 24 of Set 15 | liepaja
# Processing Record 25 of Set 15 | bontang
# Processing Record 26 of Set 15 | itarema
# Processing Record 27 of Set 15 | shakhtinsk
# Processing Record 28 of Set 15 | farah
# Processing Record 29 of Set 15 | merauke
# Processing Record 30 of Set 15 | hollister
# Processing Record 31 of Set 15 | puerto maldonado
# Processing Record 32 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 15 | natal
# Processing Record 34 of Set 15 | naron
# Processing Record 35 of Set 15 | basco
# Processing Record 36 of Set 15 | ouallam
# Processing Record 37 of Set 15 | lae
# Processing Record 38 of Set 15 | xuzhou
# Processing Record 39 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 40 of Set 15 | ancud
# Processing Record 41 of Set 15 | kununurra
# Processing Record 42 of Set 15 | kaeo
# Processing Record 43 of Set 15 | borovskoy
# Processing Record 44 of Set 15 | tsabong
# Processing Record 45 of Set 15 | moundou
# Processing Record 46 of Set 15 | kenitra
# Processing Record 47 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 48 of Set 15 | amapa
# Processing Record 49 of Set 15 | beloha
# Processing Record 50 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 16 | high level
# Processing Record 2 of Set 16 | san cristobal
# Processing Record 3 of Set 16 | jaru
# Processing Record 4 of Set 16 | stoyba
# City not found. Skipping...
# Processing Record 5 of Set 16 | qingdao
# Processing Record 6 of Set 16 | los altos
# Processing Record 7 of Set 16 | bolshiye uki
# City not found. Skipping...
# Processing Record 8 of Set 16 | little current
# Processing Record 9 of Set 16 | kuruman
# Processing Record 10 of Set 16 | sisimiut
# Processing Record 11 of Set 16 | new amsterdam
# Processing Record 12 of Set 16 | noshiro
# Processing Record 13 of Set 16 | hovd
# Processing Record 14 of Set 16 | la asuncion
# Processing Record 15 of Set 16 | dunaharaszti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     52.81        65          28
# 1        Omsukchan      RU  62.5333  155.8000     16.81        87         100
# 2     Punta Arenas      CL -53.1500  -70.9167     46.51        81          20
# 3             Sapa      PH   5.1544  120.3241     83.08        72          89
# 4             Soyo      AO  -6.1349   12.3689     77.38        89          87
# 5           Albany      US  42.6001  -73.9662     61.21        39          71
# 6             Hilo      US  19.7297 -155.0900     84.27        88         100
# 7        Romanovka      RU  51.7443   42.7527     43.90        75          96
# 8       Butaritari      KI   3.0707  172.7902     81.77        73          34
# 9  Arraial Do Cabo      BR -22.9661  -42.0278     72.88        67           1
#
#    Wind Speed Current Description
# 0       35.21    scattered clouds
# 1        6.31     overcast clouds
# 2       19.57          light rain
# 3        5.79     overcast clouds
# 4        3.47     overcast clouds
# 5        9.98       broken clouds
# 6        9.22          light rain
# 7        6.51     overcast clouds
# 8       11.18          light rain
# 9       20.94           clear sky

# %%
###Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
